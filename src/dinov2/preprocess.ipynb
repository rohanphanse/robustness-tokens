# %%
from dinov2.data.datasets import ImageNet

root = "../../imagenet_subset"              
extra = "../../imagenet_subset_extra" 

for split in [ImageNet.Split.TRAIN, ImageNet.Split.VAL]:
    dataset = ImageNet(split=split, root=root, extra=extra)
    dataset.dump_extra()
